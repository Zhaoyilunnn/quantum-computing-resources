# %%
import argparse
from collections import defaultdict
from time import time

from tqec.computation.block_graph import BlockGraph
from tqec.computation.cube import ZXCube
from tqec.gallery import cnot, steane_encoding
from tqec.interop.pyzx.correlation import _find_correlation_surfaces_from_leaf
from tqec.interop.pyzx.positioned import PositionedZX



graph = steane_encoding()
# graph = cnot()

correlation_surfaces = graph.find_correlation_surfaces()
positioned_zx = PositionedZX.from_block_graph(graph)
zx_g = positioned_zx.g
p2v = positioned_zx.p2v

# 2. Get leaf nodes
leaf_cubes = graph.leaf_cubes
leaves = {p2v[cube.position] for cube in leaf_cubes}

# This is the function we want to test
surfaces_from_first_leaf = _find_correlation_surfaces_from_leaf(zx_g, leaves.pop())

print("Original Steane Encoding:")
print(f" - Total surfaces found: {len(correlation_surfaces)}")
print(f" - Surfaces from first leaf: {len(surfaces_from_first_leaf)}")
# Out:
# Original Steane Encoding:
#  - Total surfaces found: 7
#  - Surfaces from first leaf: 15

# %%
graph.view_as_html(
    pop_faces_at_directions=("-Y",),
    show_correlation_surface=correlation_surfaces[0],
)
# Out:
# <iframe style="width: 100%; height: 300px; overflow: hidden; resize: both; border: 1px dashed gray;" frameBorder="0" srcdoc="
# &lt;!doctype html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;script type=&quot;importmap&quot;&gt;
#       {
#         &quot;imports&quot;: {
#           &quot;three&quot;: &quot;https://unpkg.com/three@0.138.0/build/three.module.js&quot;,
#           &quot;three-orbitcontrols&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/controls/OrbitControls.js&quot;,
#           &quot;three-collada-loader&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/loaders/ColladaLoader.js&quot;
#         }
#       }
#     &lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;a download=&quot;model.dae&quot; id=&quot;model-download-link&quot;      href=&quot;data:text/plain;base64,...&quot;&gt;
#     Download 3D Model as .dae File
#   &lt;/a&gt;
# ...

# %%
graph.view_as_html(
    pop_faces_at_directions=("-Y",),
    show_correlation_surface=correlation_surfaces[1],
)
# Out:
# <iframe style="width: 100%; height: 300px; overflow: hidden; resize: both; border: 1px dashed gray;" frameBorder="0" srcdoc="
# &lt;!doctype html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;script type=&quot;importmap&quot;&gt;
#       {
#         &quot;imports&quot;: {
#           &quot;three&quot;: &quot;https://unpkg.com/three@0.138.0/build/three.module.js&quot;,
#           &quot;three-orbitcontrols&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/controls/OrbitControls.js&quot;,
#           &quot;three-collada-loader&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/loaders/ColladaLoader.js&quot;
#         }
#       }
#     &lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;a download=&quot;model.dae&quot; id=&quot;model-download-link&quot;      href=&quot;data:text/plain;base64,...&quot;&gt;
#     Download 3D Model as .dae File
#   &lt;/a&gt;
# ...

# %%
graph.view_as_html(
    pop_faces_at_directions=("-Y",),
    show_correlation_surface=correlation_surfaces[2],
)
# Out:
# <iframe style="width: 100%; height: 300px; overflow: hidden; resize: both; border: 1px dashed gray;" frameBorder="0" srcdoc="
# &lt;!doctype html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;script type=&quot;importmap&quot;&gt;
#       {
#         &quot;imports&quot;: {
#           &quot;three&quot;: &quot;https://unpkg.com/three@0.138.0/build/three.module.js&quot;,
#           &quot;three-orbitcontrols&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/controls/OrbitControls.js&quot;,
#           &quot;three-collada-loader&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/loaders/ColladaLoader.js&quot;
#         }
#       }
#     &lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;a download=&quot;model.dae&quot; id=&quot;model-download-link&quot;      href=&quot;data:text/plain;base64,...&quot;&gt;
#     Download 3D Model as .dae File
#   &lt;/a&gt;
# ...

# %%
graph.view_as_html(
    pop_faces_at_directions=("-Y",),
    show_correlation_surface=correlation_surfaces[3],
)
# Out:
# <iframe style="width: 100%; height: 300px; overflow: hidden; resize: both; border: 1px dashed gray;" frameBorder="0" srcdoc="
# &lt;!doctype html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;script type=&quot;importmap&quot;&gt;
#       {
#         &quot;imports&quot;: {
#           &quot;three&quot;: &quot;https://unpkg.com/three@0.138.0/build/three.module.js&quot;,
#           &quot;three-orbitcontrols&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/controls/OrbitControls.js&quot;,
#           &quot;three-collada-loader&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/loaders/ColladaLoader.js&quot;
#         }
#       }
#     &lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;a download=&quot;model.dae&quot; id=&quot;model-download-link&quot;      href=&quot;data:text/plain;base64,...&quot;&gt;
#     Download 3D Model as .dae File
#   &lt;/a&gt;
# ...

# %%
graph.view_as_html(
    pop_faces_at_directions=("-Y",),
    show_correlation_surface=correlation_surfaces[4],
)
# Out:
# <iframe style="width: 100%; height: 300px; overflow: hidden; resize: both; border: 1px dashed gray;" frameBorder="0" srcdoc="
# &lt;!doctype html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;script type=&quot;importmap&quot;&gt;
#       {
#         &quot;imports&quot;: {
#           &quot;three&quot;: &quot;https://unpkg.com/three@0.138.0/build/three.module.js&quot;,
#           &quot;three-orbitcontrols&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/controls/OrbitControls.js&quot;,
#           &quot;three-collada-loader&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/loaders/ColladaLoader.js&quot;
#         }
#       }
#     &lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;a download=&quot;model.dae&quot; id=&quot;model-download-link&quot;      href=&quot;data:text/plain;base64,...&quot;&gt;
#     Download 3D Model as .dae File
#   &lt;/a&gt;
# ...

# %%
graph.view_as_html(
    pop_faces_at_directions=("-Y",),
    show_correlation_surface=correlation_surfaces[5],
)
# Out:
# <iframe style="width: 100%; height: 300px; overflow: hidden; resize: both; border: 1px dashed gray;" frameBorder="0" srcdoc="
# &lt;!doctype html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;script type=&quot;importmap&quot;&gt;
#       {
#         &quot;imports&quot;: {
#           &quot;three&quot;: &quot;https://unpkg.com/three@0.138.0/build/three.module.js&quot;,
#           &quot;three-orbitcontrols&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/controls/OrbitControls.js&quot;,
#           &quot;three-collada-loader&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/loaders/ColladaLoader.js&quot;
#         }
#       }
#     &lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;a download=&quot;model.dae&quot; id=&quot;model-download-link&quot;      href=&quot;data:text/plain;base64,...&quot;&gt;
#     Download 3D Model as .dae File
#   &lt;/a&gt;
# ...

# %%
graph.view_as_html(
    pop_faces_at_directions=("-Y",),
    show_correlation_surface=correlation_surfaces[6],
)
# Out:
# <iframe style="width: 100%; height: 300px; overflow: hidden; resize: both; border: 1px dashed gray;" frameBorder="0" srcdoc="
# &lt;!doctype html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;script type=&quot;importmap&quot;&gt;
#       {
#         &quot;imports&quot;: {
#           &quot;three&quot;: &quot;https://unpkg.com/three@0.138.0/build/three.module.js&quot;,
#           &quot;three-orbitcontrols&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/controls/OrbitControls.js&quot;,
#           &quot;three-collada-loader&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/loaders/ColladaLoader.js&quot;
#         }
#       }
#     &lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;a download=&quot;model.dae&quot; id=&quot;model-download-link&quot;      href=&quot;data:text/plain;base64,...&quot;&gt;
#     Download 3D Model as .dae File
#   &lt;/a&gt;
# ...

# %%
graph.view_as_html(
    pop_faces_at_directions=("-Y",),
    show_correlation_surface=surfaces_from_first_leaf[0],
)
# Out:
# <iframe style="width: 100%; height: 300px; overflow: hidden; resize: both; border: 1px dashed gray;" frameBorder="0" srcdoc="
# &lt;!doctype html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;script type=&quot;importmap&quot;&gt;
#       {
#         &quot;imports&quot;: {
#           &quot;three&quot;: &quot;https://unpkg.com/three@0.138.0/build/three.module.js&quot;,
#           &quot;three-orbitcontrols&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/controls/OrbitControls.js&quot;,
#           &quot;three-collada-loader&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/loaders/ColladaLoader.js&quot;
#         }
#       }
#     &lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;a download=&quot;model.dae&quot; id=&quot;model-download-link&quot;      href=&quot;data:text/plain;base64,...&quot;&gt;
#     Download 3D Model as .dae File
#   &lt;/a&gt;
# ...

# %%
graph.view_as_html(
    pop_faces_at_directions=("-Y",),
    show_correlation_surface=surfaces_from_first_leaf[1],
)
# Out:
# <iframe style="width: 100%; height: 300px; overflow: hidden; resize: both; border: 1px dashed gray;" frameBorder="0" srcdoc="
# &lt;!doctype html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;script type=&quot;importmap&quot;&gt;
#       {
#         &quot;imports&quot;: {
#           &quot;three&quot;: &quot;https://unpkg.com/three@0.138.0/build/three.module.js&quot;,
#           &quot;three-orbitcontrols&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/controls/OrbitControls.js&quot;,
#           &quot;three-collada-loader&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/loaders/ColladaLoader.js&quot;
#         }
#       }
#     &lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;a download=&quot;model.dae&quot; id=&quot;model-download-link&quot;      href=&quot;data:text/plain;base64,...&quot;&gt;
#     Download 3D Model as .dae File
#   &lt;/a&gt;
# ...

# %%
graph.view_as_html(
    pop_faces_at_directions=("-Y",),
    show_correlation_surface=surfaces_from_first_leaf[2],
)
# Out:
# <iframe style="width: 100%; height: 300px; overflow: hidden; resize: both; border: 1px dashed gray;" frameBorder="0" srcdoc="
# &lt;!doctype html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;script type=&quot;importmap&quot;&gt;
#       {
#         &quot;imports&quot;: {
#           &quot;three&quot;: &quot;https://unpkg.com/three@0.138.0/build/three.module.js&quot;,
#           &quot;three-orbitcontrols&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/controls/OrbitControls.js&quot;,
#           &quot;three-collada-loader&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/loaders/ColladaLoader.js&quot;
#         }
#       }
#     &lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;a download=&quot;model.dae&quot; id=&quot;model-download-link&quot;      href=&quot;data:text/plain;base64,...&quot;&gt;
#     Download 3D Model as .dae File
#   &lt;/a&gt;
# ...

# %%
graph.view_as_html(
    pop_faces_at_directions=("-Y",),
    show_correlation_surface=surfaces_from_first_leaf[3],
)
# Out:
# <iframe style="width: 100%; height: 300px; overflow: hidden; resize: both; border: 1px dashed gray;" frameBorder="0" srcdoc="
# &lt;!doctype html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;script type=&quot;importmap&quot;&gt;
#       {
#         &quot;imports&quot;: {
#           &quot;three&quot;: &quot;https://unpkg.com/three@0.138.0/build/three.module.js&quot;,
#           &quot;three-orbitcontrols&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/controls/OrbitControls.js&quot;,
#           &quot;three-collada-loader&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/loaders/ColladaLoader.js&quot;
#         }
#       }
#     &lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;a download=&quot;model.dae&quot; id=&quot;model-download-link&quot;      href=&quot;data:text/plain;base64,...&quot;&gt;
#     Download 3D Model as .dae File
#   &lt;/a&gt;
# ...

# %%
graph.view_as_html(
    pop_faces_at_directions=("-Y",),
    show_correlation_surface=surfaces_from_first_leaf[4],
)
# Out:
# <iframe style="width: 100%; height: 300px; overflow: hidden; resize: both; border: 1px dashed gray;" frameBorder="0" srcdoc="
# &lt;!doctype html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;script type=&quot;importmap&quot;&gt;
#       {
#         &quot;imports&quot;: {
#           &quot;three&quot;: &quot;https://unpkg.com/three@0.138.0/build/three.module.js&quot;,
#           &quot;three-orbitcontrols&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/controls/OrbitControls.js&quot;,
#           &quot;three-collada-loader&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/loaders/ColladaLoader.js&quot;
#         }
#       }
#     &lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;a download=&quot;model.dae&quot; id=&quot;model-download-link&quot;      href=&quot;data:text/plain;base64,...&quot;&gt;
#     Download 3D Model as .dae File
#   &lt;/a&gt;
# ...

# %%
graph.view_as_html(
    pop_faces_at_directions=("-Y",),
    show_correlation_surface=surfaces_from_first_leaf[5],
)
# Out:
# <iframe style="width: 100%; height: 300px; overflow: hidden; resize: both; border: 1px dashed gray;" frameBorder="0" srcdoc="
# &lt;!doctype html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;script type=&quot;importmap&quot;&gt;
#       {
#         &quot;imports&quot;: {
#           &quot;three&quot;: &quot;https://unpkg.com/three@0.138.0/build/three.module.js&quot;,
#           &quot;three-orbitcontrols&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/controls/OrbitControls.js&quot;,
#           &quot;three-collada-loader&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/loaders/ColladaLoader.js&quot;
#         }
#       }
#     &lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;a download=&quot;model.dae&quot; id=&quot;model-download-link&quot;      href=&quot;data:text/plain;base64,...&quot;&gt;
#     Download 3D Model as .dae File
#   &lt;/a&gt;
# ...

# %%
graph.view_as_html(
    pop_faces_at_directions=("-Y",),
    show_correlation_surface=surfaces_from_first_leaf[6],
)
# Out:
# <iframe style="width: 100%; height: 300px; overflow: hidden; resize: both; border: 1px dashed gray;" frameBorder="0" srcdoc="
# &lt;!doctype html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;script type=&quot;importmap&quot;&gt;
#       {
#         &quot;imports&quot;: {
#           &quot;three&quot;: &quot;https://unpkg.com/three@0.138.0/build/three.module.js&quot;,
#           &quot;three-orbitcontrols&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/controls/OrbitControls.js&quot;,
#           &quot;three-collada-loader&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/loaders/ColladaLoader.js&quot;
#         }
#       }
#     &lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;a download=&quot;model.dae&quot; id=&quot;model-download-link&quot;      href=&quot;data:text/plain;base64,...&quot;&gt;
#     Download 3D Model as .dae File
#   &lt;/a&gt;
# ...

# %%
graph.view_as_html(
    pop_faces_at_directions=("-Y",),
    show_correlation_surface=surfaces_from_first_leaf[7],
)
# Out:
# <iframe style="width: 100%; height: 300px; overflow: hidden; resize: both; border: 1px dashed gray;" frameBorder="0" srcdoc="
# &lt;!doctype html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;script type=&quot;importmap&quot;&gt;
#       {
#         &quot;imports&quot;: {
#           &quot;three&quot;: &quot;https://unpkg.com/three@0.138.0/build/three.module.js&quot;,
#           &quot;three-orbitcontrols&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/controls/OrbitControls.js&quot;,
#           &quot;three-collada-loader&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/loaders/ColladaLoader.js&quot;
#         }
#       }
#     &lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;a download=&quot;model.dae&quot; id=&quot;model-download-link&quot;      href=&quot;data:text/plain;base64,...&quot;&gt;
#     Download 3D Model as .dae File
#   &lt;/a&gt;
# ...

# %%
graph.view_as_html(
    pop_faces_at_directions=("-Y",),
    show_correlation_surface=surfaces_from_first_leaf[8],
)
# Out:
# <iframe style="width: 100%; height: 300px; overflow: hidden; resize: both; border: 1px dashed gray;" frameBorder="0" srcdoc="
# &lt;!doctype html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;script type=&quot;importmap&quot;&gt;
#       {
#         &quot;imports&quot;: {
#           &quot;three&quot;: &quot;https://unpkg.com/three@0.138.0/build/three.module.js&quot;,
#           &quot;three-orbitcontrols&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/controls/OrbitControls.js&quot;,
#           &quot;three-collada-loader&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/loaders/ColladaLoader.js&quot;
#         }
#       }
#     &lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;a download=&quot;model.dae&quot; id=&quot;model-download-link&quot;      href=&quot;data:text/plain;base64,...&quot;&gt;
#     Download 3D Model as .dae File
#   &lt;/a&gt;
# ...

# %%
graph.view_as_html(
    pop_faces_at_directions=("-Y",),
    show_correlation_surface=surfaces_from_first_leaf[9],
)
# Out:
# <iframe style="width: 100%; height: 300px; overflow: hidden; resize: both; border: 1px dashed gray;" frameBorder="0" srcdoc="
# &lt;!doctype html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;script type=&quot;importmap&quot;&gt;
#       {
#         &quot;imports&quot;: {
#           &quot;three&quot;: &quot;https://unpkg.com/three@0.138.0/build/three.module.js&quot;,
#           &quot;three-orbitcontrols&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/controls/OrbitControls.js&quot;,
#           &quot;three-collada-loader&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/loaders/ColladaLoader.js&quot;
#         }
#       }
#     &lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;a download=&quot;model.dae&quot; id=&quot;model-download-link&quot;      href=&quot;data:text/plain;base64,...&quot;&gt;
#     Download 3D Model as .dae File
#   &lt;/a&gt;
# ...

# %%
graph.view_as_html(
    pop_faces_at_directions=("-Y",),
    show_correlation_surface=surfaces_from_first_leaf[10],
)
# Out:
# <iframe style="width: 100%; height: 300px; overflow: hidden; resize: both; border: 1px dashed gray;" frameBorder="0" srcdoc="
# &lt;!doctype html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;script type=&quot;importmap&quot;&gt;
#       {
#         &quot;imports&quot;: {
#           &quot;three&quot;: &quot;https://unpkg.com/three@0.138.0/build/three.module.js&quot;,
#           &quot;three-orbitcontrols&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/controls/OrbitControls.js&quot;,
#           &quot;three-collada-loader&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/loaders/ColladaLoader.js&quot;
#         }
#       }
#     &lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;a download=&quot;model.dae&quot; id=&quot;model-download-link&quot;      href=&quot;data:text/plain;base64,...&quot;&gt;
#     Download 3D Model as .dae File
#   &lt;/a&gt;
# ...

# %%
graph.view_as_html(
    pop_faces_at_directions=("-Y",),
    show_correlation_surface=surfaces_from_first_leaf[11],
)
# Out:
# <iframe style="width: 100%; height: 300px; overflow: hidden; resize: both; border: 1px dashed gray;" frameBorder="0" srcdoc="
# &lt;!doctype html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;script type=&quot;importmap&quot;&gt;
#       {
#         &quot;imports&quot;: {
#           &quot;three&quot;: &quot;https://unpkg.com/three@0.138.0/build/three.module.js&quot;,
#           &quot;three-orbitcontrols&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/controls/OrbitControls.js&quot;,
#           &quot;three-collada-loader&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/loaders/ColladaLoader.js&quot;
#         }
#       }
#     &lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;a download=&quot;model.dae&quot; id=&quot;model-download-link&quot;      href=&quot;data:text/plain;base64,...&quot;&gt;
#     Download 3D Model as .dae File
#   &lt;/a&gt;
# ...

# %%
graph.view_as_html(
    pop_faces_at_directions=("-Y",),
    show_correlation_surface=surfaces_from_first_leaf[12],
)
# Out:
# <iframe style="width: 100%; height: 300px; overflow: hidden; resize: both; border: 1px dashed gray;" frameBorder="0" srcdoc="
# &lt;!doctype html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;script type=&quot;importmap&quot;&gt;
#       {
#         &quot;imports&quot;: {
#           &quot;three&quot;: &quot;https://unpkg.com/three@0.138.0/build/three.module.js&quot;,
#           &quot;three-orbitcontrols&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/controls/OrbitControls.js&quot;,
#           &quot;three-collada-loader&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/loaders/ColladaLoader.js&quot;
#         }
#       }
#     &lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;a download=&quot;model.dae&quot; id=&quot;model-download-link&quot;      href=&quot;data:text/plain;base64,...&quot;&gt;
#     Download 3D Model as .dae File
#   &lt;/a&gt;
# ...

# %%
graph.view_as_html(
    pop_faces_at_directions=("-Y",),
    show_correlation_surface=surfaces_from_first_leaf[13],
)
# Out:
# <iframe style="width: 100%; height: 300px; overflow: hidden; resize: both; border: 1px dashed gray;" frameBorder="0" srcdoc="
# &lt;!doctype html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;script type=&quot;importmap&quot;&gt;
#       {
#         &quot;imports&quot;: {
#           &quot;three&quot;: &quot;https://unpkg.com/three@0.138.0/build/three.module.js&quot;,
#           &quot;three-orbitcontrols&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/controls/OrbitControls.js&quot;,
#           &quot;three-collada-loader&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/loaders/ColladaLoader.js&quot;
#         }
#       }
#     &lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;a download=&quot;model.dae&quot; id=&quot;model-download-link&quot;      href=&quot;data:text/plain;base64,...&quot;&gt;
#     Download 3D Model as .dae File
#   &lt;/a&gt;
# ...

# %%
graph.view_as_html(
    pop_faces_at_directions=("-Y",),
    show_correlation_surface=surfaces_from_first_leaf[14],
)
# Out:
# <iframe style="width: 100%; height: 300px; overflow: hidden; resize: both; border: 1px dashed gray;" frameBorder="0" srcdoc="
# &lt;!doctype html&gt;
# &lt;html&gt;
#
# &lt;head&gt;
#   &lt;meta charset=&quot;UTF-8&quot; /&gt;
#   &lt;script type=&quot;importmap&quot;&gt;
#       {
#         &quot;imports&quot;: {
#           &quot;three&quot;: &quot;https://unpkg.com/three@0.138.0/build/three.module.js&quot;,
#           &quot;three-orbitcontrols&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/controls/OrbitControls.js&quot;,
#           &quot;three-collada-loader&quot;: &quot;https://unpkg.com/three@0.138.0/examples/jsm/loaders/ColladaLoader.js&quot;
#         }
#       }
#     &lt;/script&gt;
# &lt;/head&gt;
#
# &lt;body&gt;
#   &lt;a download=&quot;model.dae&quot; id=&quot;model-download-link&quot;      href=&quot;data:text/plain;base64,...&quot;&gt;
#     Download 3D Model as .dae File
#   &lt;/a&gt;
# ...
